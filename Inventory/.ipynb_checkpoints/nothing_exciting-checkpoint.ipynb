# %%
import pandas as pd

# %%
core = pd.read_csv("data/core_dataset.csv")
hr = pd.read_csv("data/HRDataset_v9.csv")
recruit = pd.read_csv("data/recruiting_costs.csv")
produce = pd.read_csv("data/production_staff.csv")
salary = pd.read_csv("data/salary_grid.csv")

# %%
pd.options.display.max_columns = None

# %%
core.shape
# Out:
# (302, 21)

# %%
hr["Department"].value_counts()
# Out:
# Production              208
# IT/IS                    50
# Sales                    31
# Admin Offices            10
# Software Engineering     10
# Executive Office          1
# Name: Department, dtype: int64

# %%
hr["Reason For Term"].value_counts()
# Out:
# N/A - still employed                197
# Another position                     20
# unhappy                              14
# N/A - Has not started yet            11
# more money                           11
# career change                         9
# hours                                 9
# attendance                            7
# relocation out of area                5
# return to school                      5
# retiring                              4
# military                              4
# performance                           4
# medical issues                        3
# no-call, no-show                      3
# maternity leave - did not return      3
# gross misconduct                      1
# Name: Reason For Term, dtype: int64

# %%
hr.head()
# Out:
#           Employee Name  Employee Number  MarriedID  MaritalStatusID  \
# 0            Brown, Mia       1103024456          1                1
# 1  LaRotonda, William         1106026572          0                2
# 2      Steans, Tyrone         1302053333          0                0
# 3       Howard, Estelle       1211050782          1                1
# 4           Singh, Nan        1307059817          0                0
#
#    GenderID  EmpStatus_ID  DeptID  Perf_ScoreID  Age  Pay Rate State   Zip  \
# 0         0             1       1             3   30     28.50    MA  1450
# 1         1             1       1             3   34     23.00    MA  1460
# 2         1             1       1             3   31     29.00    MA  2703
# 3         0             1       1             9   32     21.50    MA  2170
# 4         0             1       1             9   30     16.56    MA  2330
#
#           DOB     Sex MaritalDesc CitizenDesc Hispanic/Latino  \
# ...
