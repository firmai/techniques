# %%
# !ls
# Out:
# Data-Analysis_Derek.xlsx EDA.ipynb

# %%
import pandas as pd

# %%
df = pd.read_csv("df2.csv")

# %%
df.head()
# Out:
#    ID A.1_5_Op-HQ_Country A.1_6_Op-HQ_City  A.1_7_Legal-HQ_Country  \
# 0   1                  UK           London                      UK
# 1   2                 USA           Denver  British Virgin Islands
# 2   3                  UK              NaN                      UK
# 3   4              Brazil        Sao Paulo                  Brazil
# 4   5               China         Hangzhou                   China
#
#   A.1_5_Op-HQ_Region A.1_7_Legal-HQ_Region A.1_8_Initial-Exploration_Year  \
# 0             Europe                Europe                           2014
# 1      North America         North America                           2016
# 2             Europe                Europe                           2015
# 3                LAC                   LAC                           2016
# 4               APAC                  APAC                           2016
#
#    A.1_9_Launch_Year  A.1_9_Development-Timelag_YR A.1_Blockchain-Native  \
# ...

# %%
df_sanstext = df.select_dtypes(include=['float64',"int"])

# %%
df.shape
# Out:
# (60, 202)

# %%
df2 = pd.DataFrame(index=df_sanstext.mean().dropna().index)

# %%
df2["mean"] = df_sanstext.mean().dropna()

# %%
df2["median"] = df_sanstext.median().dropna()

# %%
df2["max"] = df_sanstext.max().dropna()

# %%
df2["min"] = df_sanstext.min().dropna()

# %%
df2["range"] = df2["max"] - df2["min"]

# %%
df2["standard_deviation"] = df_sanstext.std().dropna()

# %%
df2 = df2.round(2)

# %%
df2
# Out:
#                                                         mean   median  \
# ID                                                     42.20    32.50
# A.1_9_Launch_Year                                    2016.81  2017.00
# A.1_9_Development-Timelag_YR                            1.46     1.00
# A.4_1_1_FTE_2016_Total                              11179.09     9.00
# A.4_1_2_FTE_2016_BC-Exclusively                        20.72     4.00
# A.4_2_1_FTE_2017_Total                               9646.04    10.00
# A.4_2_2_FTE_2017_BC-Exclusively                        50.80     7.00
# A.4_3_1_FTE_2018_Total                               9077.93    20.00
# A.4_3_2_FTE_2018Q2_BC-Exclusively                     122.75    10.00
# A.4_2016-Ratio                                          0.53     0.50
# A.4_2017-Ratio                                          0.57     0.60
# A.4_2018Q2-Ratio                                        0.59     0.66
# ...

# %%
df2.to_csv("aggs.csv")

# %%
df_agg = pd.DataFrame(df.mean`a
                      (), df.median(), df.max())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/anaconda/envs/py36/lib/python3.6/site-packages/pandas/core/internals.py in create_block_manager_from_blocks(blocks, axes)
#    4856                 blocks = [make_block(values=blocks[0],
# -> 4857                                      placement=slice(0, len(axes[0])))]
#    4858
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/pandas/core/internals.py in make_block(values, placement, klass, ndim, dtype, fastpath)
#    3204
# -> 3205     return klass(values, ndim=ndim, placement=placement)
#    3206
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/pandas/core/internals.py in __init__(self, values, placement, ndim)
#     124                 'Wrong number of items passed {val}, placement implies '
# --> 125                 '{mgr}'.format(val=len(self.values), mgr=len(self.mgr_locs)))
#     126
#
# ...

# %%
df.mean()
# Out:
# ID                                                                       42.200000
# A.1_9_Launch_Year                                                      2016.811321
# A.1_9_Development-Timelag_YR                                              1.458333
# A.4_2016-Ratio                                                            0.534524
# A.4_2017-Ratio                                                            0.571373
# A.4_2018Q2-Ratio                                                          0.592679
# A.5_1_%_Engineers-Devs                                                   52.890909
# A.5_2_%_Strategists-Consultants                                          17.490566
# A.5_3_%_Sales                                                            10.018868
# A.5_4_%_Business-Dev                                                     13.867925
# A.5_5_%_Legal                                                             3.207547
# ...

# %%
df["A.2_Layer"].value_counts()
# Out:
# Network,Application             15
# Protocol,Network,Application    15
# Application                     12
# Protocol                         9
# Protocol,Network                 6
# Protocol,Application             2
# Network                          1
# Name: A.2_Layer, dtype: int64

# %%
df_num = df[["A.1_Blockchain-Native","A.4_1_1_FTE_2016_Total","A.4_1_2_FTE_2016_BC-Exclusively","A.4_2_1_FTE_2017_Total","A.4_2_2_FTE_2017_BC-Exclusively"]].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-0cbf4c7ab186> in <module>()
# ----> 1 df_num = df[["A.1_Blockchain-Native","A.4_1_1_FTE_2016_Total","A.4_1_2_FTE_2016_BC-Exclusively","A.4_2_1_FTE_2017_Total","A.4_2_2_FTE_2017_BC-Exclusively"]].astype(float)
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     176                 else:
#     177                     kwargs[new_arg_name] = new_arg_value
# --> 178             return func(*args, **kwargs)
#     179         return wrapper
#     180     return _deprecate_kwarg
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4999             # else, only a single dtype is given
#    5000             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# ...

# %%
# %matplotlib inline

df[["A.1_Blockchain-Native","A.4_1_1_FTE_2016_Total","A.4_1_2_FTE_2016_BC-Exclusively","A.4_2_1_FTE_2017_Total","A.4_2_2_FTE_2017_BC-Exclusively"]].groupby("A.1_Blockchain-Native").mean().round(2).hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x129a4a470>,
# ...
#       dtype=object)

# %%
import numpy as np
import matplotlib.pyplot as plt


N = 5
menMeans = (20, 35, 30, 35, 27)
womenMeans = (25, 32, 34, 20, 25)
menStd = (2, 3, 4, 1, 2)
womenStd = (3, 5, 2, 3, 3)
ind = np.arange(N)    # the x locations for the groups
width = 0.35       # the width of the bars: can also be len(x) sequence

p1 = plt.bar(ind, menMeans, width, yerr=menStd)
p2 = plt.bar(ind, womenMeans, width,
             bottom=menMeans, yerr=womenStd)

plt.ylabel('Scores')
plt.title('Scores by group and gender')
plt.xticks(ind, ('G1', 'G2', 'G3', 'G4', 'G5'))
plt.yticks(np.arange(0, 81, 10))
plt.legend((p1[0], p2[0]), ('Men', 'Women'))

plt.show()

# %%
df_sanstext = df_sanstext.reset_index(drop=True)

# %%
df_sanstext.columns
# Out:
# Index(['ID', 'A.1_9_Launch_Year', 'A.1_9_Development-Timelag_YR',
#        'A.4_1_1_FTE_2016_Total', 'A.4_1_2_FTE_2016_BC-Exclusively',
#        'A.4_2_1_FTE_2017_Total', 'A.4_2_2_FTE_2017_BC-Exclusively',
#        'A.4_3_1_FTE_2018_Total', 'A.4_3_2_FTE_2018Q2_BC-Exclusively',
#        'A.4_2016-Ratio', 'A.4_2017-Ratio', 'A.4_2018Q2-Ratio',
#        'A.5_1_%_Engineers-Devs', 'A.5_2_%_Strategists-Consultants',
#        'A.5_3_%_Sales', 'A.5_4_%_Business-Dev', 'A.5_5_%_Legal',
#        'A.5_6_%_Other', 'B.5_4_TEXT_Based-Protocol_Other',
#        'C.5#2_1_1_Core-Protocol_Hyperledger_Additional-Comments',
#        'C.5#2_4_1_Core-Protocol_ChainCore_Additional-Comments',
#        'C.5#2_7_1_Core-Protocol_Autononity_Additional-Comments',
#        'C.5#2_8_1_Core-Protocol_Quorum_Additional-Comments',
#        'C.5#2_9_1_Core-Protocol_SETL_Additional-Comments',
#        'C.5#2_10_1_Core-Protocol_Digital-Asset-Platform_Additional-Comments',
# ...

# %%
df_sanstext
# Out:
#      ID  A.1_9_Launch_Year  A.1_9_Development-Timelag_YR  \
# 0     1             2015.0                           1.0
# 1     2                NaN                           NaN
# 2     3             2019.0                           4.0
# 3     4                NaN                           NaN
# 4     5                NaN                           NaN
# 5     6                NaN                           NaN
# 6     7                NaN                           NaN
# 7     8             2018.0                           1.0
# 8     9             2014.0                           0.0
# 9    10             2018.0                           0.0
# 10   11             2018.0                           0.0
# 11   12             2017.0                           3.0
# 12   13             2018.0                           4.0
# 13   14             2017.0                           1.0
# 14   15             2017.0                           2.0
# ...

# %%
pd.crosstab(df_sanstext,columns=[["A.4_1_2_FTE_2016_BC-Exclusively","A.4_2_1_FTE_2017_Total","A.4_2_2_FTE_2017_BC-Exclusively"]])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/anaconda/envs/py36/lib/python3.6/site-packages/pandas/core/internals.py in create_block_manager_from_arrays(arrays, names, axes)
#    4871     try:
# -> 4872         blocks = form_blocks(arrays, names, axes)
#    4873         mgr = BlockManager(blocks, axes)
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/pandas/core/internals.py in form_blocks(arrays, names, axes)
#    4937     if len(items_dict['ObjectBlock']) > 0:
# -> 4938         object_blocks = _simple_blockify(items_dict['ObjectBlock'], np.object_)
#    4939         blocks.extend(object_blocks)
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/pandas/core/internals.py in _simple_blockify(tuples, dtype)
#    4975     """
# -> 4976     values, placement = _stack_arrays(tuples, dtype)
#    4977
#
# ...

# %%
import numpy as np
pd.pivot_table(df, values="A.2_Layer",index=[,],columns=[["A.4_1_2_FTE_2016_BC-Exclusively","A.4_2_1_FTE_2017_Total","A.4_2_2_FTE_2017_BC-Exclusively"]], aggfunc=np.sum)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-89-d1ec2abb58f4> in <module>()
#       1 import numpy as np
# ----> 2 pd.pivot_table(df, values="A.2_Layer",index=["A.1_Blockchain-Native","A.4_1_1_FTE_2016_Total"],columns=[["A.4_1_2_FTE_2016_BC-Exclusively","A.4_2_1_FTE_2017_Total","A.4_2_2_FTE_2017_BC-Exclusively"]], aggfunc=np.sum)
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/pandas/core/reshape/pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name)
#      84     # group by the cartesian product of the grouper
#      85     # if we have a categorical
# ---> 86     grouped = data.groupby(keys, observed=False)
#      87     agged = grouped.agg(aggfunc)
#      88     if dropna and isinstance(agged, ABCDataFrame) and len(agged.columns):
#
# ...

# %%
pd.crosstab(df,columns=df.columns)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-84-71ce28390c73> in <module>()
# ----> 1 pd.crosstab(df,columns=df.columns)
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/pandas/core/reshape/pivot.py in crosstab(index, columns, values, rownames, colnames, aggfunc, margins, margins_name, dropna, normalize)
#     480
#     481     from pandas import DataFrame
# --> 482     df = DataFrame(data, index=common_idx)
#     483     if values is None:
#     484         df['__dummy__'] = 0
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     346                                  dtype=dtype, copy=copy)
#     347         elif isinstance(data, dict):
# --> 348             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     349         elif isinstance(data, ma.MaskedArray):
# ...

# %%
df.groupby("A.2_Layer").apply(lambda g: g / g.sum())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda/envs/py36/lib/python3.6/site-packages/pandas/core/ops.py in na_op(x, y)
#    1496         try:
# -> 1497             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#    1498         except TypeError:
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/pandas/core/computation/expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     204     if use_numexpr:
# --> 205         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     206     return _evaluate_standard(op, op_str, a, b)
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/pandas/core/computation/expressions.py in _evaluate_numexpr(op, op_str, a, b, truediv, reversed, **eval_kwargs)
#     119     if result is None:
# --> 120         result = _evaluate_standard(op, op_str, a, b)
#     121
#
# ...

# %%
pd.set_option('display.max_columns', 500)

# %%
(len(df)-10)
# Out:
# 50

# %%
if len(df["A.1_5_Op-HQ_Country"].unique()) > (len(df)-10)
# Out:
# 24

# %%
from pandas import ExcelWriter  
w = ExcelWriter('b.xlsx')

# %%
import re
for col in df.select_dtypes(['object']).columns:
    if len(df[col].unique()) > (len(df)-10):
        continue
    gp = df.groupby(col).agg(["mean","median","max","min"])
    col= col.replace("?","")
    print(col)
    gp.to_excel(w, sheet_name=str(col[:30]))
w.save()
# Out:
# A.1_5_Op-HQ_Country
# A.1_6_Op-HQ_City
# A.1_7_Legal-HQ_Country
# A.1_5_Op-HQ_Region
# A.1_7_Legal-HQ_Region
# A.1_8_Initial-Exploration_Year
# A.1_Blockchain-Native
# A.1_Actor_Type
# A.2_Layer
# A.3_Activities
# A.3_8_TEXT_Other
# A.4_Company-Size
# A.5_6_TEXT_%_Other
# A.6_Proprietary-OpenSource
# B.1_1_Protocol-Name
# B.1_2_Start-Development
# B.1_3-Launch-Date
# B.2_Other-Protocols
# B.3_Codebase_Open-Sourced
# B.3_1_TEXT_Codebase_Fully-Open-Sourced_License
# B.3_2_TEXT_Codebase_Majority-Open-Sourced_License
# B.3_3_TEXT_Codebase_Minority-Open-Sourced_License
# B.4_Open-Sourcing_Prospects
# B.5_Based-Protocol
# B.5_1_TEXT_Substantially-Based-Protocol_Name
# B.5_2_TEXT_Loosely-Based-Protocol_Name
# B.6_Industry-Use-Case
# B.6_2_TEXT_Specific-Industry-Use-Case
# B.6_3_TEXT_Targeting-But-Flexible-Industry-Use-Case
# B.6_4_TEXT_Industry-Use-Case_Other
# B.7_Data_Broadcast
# B.7_4_TEXT_Data_Broadcast
# B.8_Consensus-Level
# B.8_4_TEXT_Consensus-Level_Other
# B.9_Consensus-Algorithm
# ...

# %%
w

# %%
df.groupby("A.2_Layer").agg(["mean","median","max","min"])
# Out:
#                                       ID                  A.1_9_Launch_Year  \
#                                     mean median  max  min              mean
# A.2_Layer
# Application                    47.333333   35.0  118    4       2016.777778
# Network                       121.000000  121.0  121  121       2015.000000
# Network,Application            39.266667   34.0  122    8       2017.357143
# Protocol                       27.666667   18.0   85    2       2017.000000
# Protocol,Application           22.000000   22.0   29   15       2016.500000
# Protocol,Network               44.166667   35.5   99    1       2016.666667
# Protocol,Network,Application   46.400000   42.0  107   16       2016.466667
#
#                                                       \
#                               median     max     min
# A.2_Layer
# Application                   2017.0  2018.0  2014.0
# Network                       2015.0  2015.0  2015.0
# ...

# %%
pd.crosstab(df["A.2_Layer"], df["A.1_9_Launch_Year"]).apply(lambda r: r/r.sum(), axis=1).plot()

# %%
wb
# Out:
# <Book [Data-Analysis_Derek.xlsx]>

# %%
df = pd.read_excel("Data-Analysis_Derek.xlsx", sheet_name=)`
# Out:
# ---------------------------------------------------------------------------
# XLRDError                                 Traceback (most recent call last)
# <ipython-input-4-8e060578511d> in <module>()
# ----> 1 df = pd.read_excel("Data-Analysis_Derek.xlsx")
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     176                 else:
#     177                     kwargs[new_arg_name] = new_arg_value
# --> 178             return func(*args, **kwargs)
#     179         return wrapper
#     180     return _deprecate_kwarg
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     176                 else:
#     177                     kwargs[new_arg_name] = new_arg_value
# --> 178             return func(*args, **kwargs)
#     179         return wrapper
#     180     return _deprecate_kwarg
#
# ...
