# %%
import nltk 
nltk.download('punkt')

import nltk
nltk.download('averaged_perceptron_tagger')

import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /Users/dereksnow/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/dereksnow/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/dereksnow/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from os import listdir
from os.path import isfile, join
mypath = "/Volumes/extra/NLP_Work/transc/"
onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]

len(onlyfiles)

rrr = [ ra for ra in onlyfiles if ".DOC" not in ra ]

rrr = [ ra for ra in rrr if "._" not in ra ]

# %%
"A_Schulman_Inc2009.txt" in rrr
# Out:
# True

# %%
from nltk.tokenize import word_tokenize, sent_tokenize, RegexpTokenizer

#sentences = sent_tokenize(text)
#words = word_tokenize(text)

import nltk
import re
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer



def process_words_file():
    """
    Read the words file and store the words in a list
    """
    global curriculum_words
    curriculum_words = []
    with open(words_file) as curriculum_file:
        try:
            for line in curriculum_file:
                curriculum_words.append(line.strip())
        except Exception as e:
            print (e)


def process_input():
    """
    Read the input file and tokenize and POS_tag the words
    """
    global pos_tagged_array
    with open(input_file) as input_text:
        try:
            for line in input_text:
                if line.strip():
                    words = word_tokenize(line)
                    for tag in nltk.pos_tag(words):
                        # eliminating unnecessary POS tags
                        match = re.search('\w.*', tag[1])
                        if match:
                            pos_tagged_array.append(tag)
        except Exception as e:
            print (e)


def lemmatize_words():
    """
    Convert each word in the input to its base form
    and save it in a list
    """
    global base_words
    global doc_len 
    doc_len = len(pos_tagged_array)
    for tag in pos_tagged_array:
        base_word = tag[0].lower()
        base_words.append(base_word)

# %%
len(pos_tagged_array)
# Out:
# 21255

# %%
pos_tagged_array
# Out:
# [('Download', 'NNP'),
#  ('Request', 'NNP'),
#  ('Tagged', 'VBN'),
#  ('Documents', 'NNS'),
#  ('12-15', 'JJ'),
#  ('Time', 'NN'),
#  ('Of', 'IN'),
#  ('Request', 'NNP'),
#  ('Saturday', 'NNP'),
#  ('April', 'NNP'),
#  ('28', 'CD'),
#  ('2018', 'CD'),
#  ('04:38:09', 'CD'),
#  ('Send', 'NN'),
#  ('To', 'TO'),
#  ('UNIVERSITY', 'NN'),
#  ('OF', 'NNP'),
#  ('LIVERPOOL', 'NNP'),
#  ('SYDNEY', 'NNP'),
#  ('JONES', 'NNP'),
#  ('LIBRARY', 'NNP'),
#  ('PO', 'NNP'),
#  ('BOX', 'NNP'),
#  ('123', 'CD'),
#  ('Terms', 'NNS'),
#  ('AAON', 'NNP'),
#  ('Inc', 'NNP'),
#  ('Source', 'NN'),
#  ('FD', 'NNP'),
#  ('Fair', 'NNP'),
#  ('Disclosure', 'NNP'),
#  ('Wire', 'NN'),
#  ('Project', 'NN'),
#  ('ID', 'NNP'),
#  ('1', 'CD'),
#  ('of', 'IN'),
#  ('4', 'CD'),
#  ('DOCUMENTS', 'NNS'),
#  ('FD', 'NNP'),
#  ('Fair', 'NNP'),
#  ('Disclosure', 'NNP'),
#  ('Wire', 'NN'),
#  ('March', 'NNP'),
#  ('10', 'CD'),
#  ('2011', 'CD'),
#  ('Thursday', 'NNP'),
#  ('Q4', 'NN'),
#  ('2010', 'CD'),
#  ('AAON', 'NNP'),
#  ('Earnings', 'NNP'),
#  ('Conference', 'NNP'),
#  ('Call', 'NNP'),
#  ('Final', 'NN'),
#  ('LENGTH', 'NN'),
#  ('5174', 'CD'),
#  ('words', 'NNS'),
#  ('Corporate', 'JJ'),
#  ('Participants', 'NNS'),
#  ('*', 'JJ'),
#  ('Norman', 'NNP'),
#  ('Asbjornson', 'NNP'),
#  ('AAON', 'NNP'),
#  ('Inc.', 'NNP'),
#  ('Chairman', 'NNP'),
#  ('CEO', 'NNP'),
#  ('President', 'NNP'),
#  ('*', 'NNP'),
#  ('Kathy', 'NNP'),
#  ('Sheffield', 'NNP'),
#  ('AAON', 'NNP'),
#  ('Inc.', 'NNP'),
#  ('VP', 'NNP'),
#  ('CFO', 'NNP'),
#  ('Conference', 'NN'),
#  ('Call', 'NN'),
#  ('Participants', 'NNS'),
#  ('*', 'JJ'),
#  ('Joe', 'NNP'),
#  ('Mondillo', 'NNP'),
#  ('Sidoti', 'NNP'),
#  ('&', 'CC'),
#  ('Company', 'NNP'),
#  ('Analyst', 'NN'),
#  ('*', 'JJ'),
#  ('Jon', 'NNP'),
#  ('Braatz', 'NNP'),
#  ('Kansas', 'NNP'),
#  ('City', 'NNP'),
#  ('Capital', 'NNP'),
#  ('Analyst', 'NN'),
#  ('Presentation', 'NN'),
#  ('OPERATOR', 'NN'),
#  ('Welcome', 'JJ'),
#  ('to', 'TO'),
#  ('AAON', 'NNP'),
#  ("'s", 'POS'),
#  ('fourth', 'JJ'),
#  ('quarter', 'NN'),
#  ('and', 'CC'),
#  ('full-year', 'JJ'),
#  ('2010', 'CD'),
#  ('sales', 'NNS'),
#  ('and', 'CC'),
#  ('earnings', 'NNS'),
#  ('conference', 'NN'),
#  ('call', 'NN'),
#  ('I', 'PRP'),
#  ('will', 'MD'),
#  ('now', 'RB'),
#  ('turn', 'VB'),
#  ('it', 'PRP'),
#  ('over', 'IN'),
#  ('to', 'TO'),
#  ('your', 'PRP$'),
#  ('host', 'NN'),
#  ('Mr.', 'NNP'),
#  ('Asbjornson', 'NNP'),
#  ('NORMAN', 'NNP'),
#  ('ASBJORNSON', 'NNP'),
#  ('CHAIRMAN', 'NNP'),
#  ('CEO', 'NNP'),
#  ('PRESIDENT', 'NNP'),
#  ('AAON', 'NNP'),
#  ('INC.', 'NNP'),
#  ('Good', 'JJ'),
#  ('afternoon', 'NN'),
#  ('Thank', 'NNP'),
#  ('you', 'PRP'),
#  ('for', 'IN'),
#  ('joining', 'VBG'),
#  ('us', 'PRP'),
#  ('for', 'IN'),
#  ('our', 'PRP$'),
#  ('2010', 'CD'),
#  ('year-end', 'NN'),
#  ('and', 'CC'),
#  ('our', 'PRP$'),
#  ('fourth-quarter', 'JJ'),
#  ('report', 'NN'),
#  ('Before', 'IN'),
#  ('beginning', 'VBG'),
#  ('I', 'PRP'),
#  ('would', 'MD'),
#  ('like', 'VB'),
#  ('to', 'TO'),
#  ('read', 'VB'),
#  ('our', 'PRP$'),
#  ('Forward-looking', 'JJ'),
#  ('disclaimer', 'NN'),
#  ('To', 'TO'),
#  ('the', 'DT'),
#  ('extend', 'NN'),
#  ('any', 'DT'),
#  ('statement', 'NN'),
#  ('presented', 'VBD'),
#  ('herein', 'JJ'),
#  ('deals', 'NNS'),
#  ('with', 'IN'),
#  ('information', 'NN'),
#  ('that', 'WDT'),
#  ('is', 'VBZ'),
#  ('not', 'RB'),
#  ('historical', 'JJ'),
#  ('including', 'VBG'),
#  ('the', 'DT'),
#  ('outlook', 'NN'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('remainder', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('year', 'NN'),
#  ('such', 'JJ'),
#  ('statement', 'NN'),
#  ('is', 'VBZ'),
#  ('necessarily', 'RB'),
#  ('Forward-looking', 'NNP'),
#  ('and', 'CC'),
#  ('made', 'VBD'),
#  ('pursuant', 'NN'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('Safe', 'NNP'),
#  ('Harbor', 'NNP'),
#  ('provisions', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('Securities', 'NNPS'),
#  ('Litigation', 'NNP'),
#  ('Reform', 'NNP'),
#  ('Act', 'NNP'),
#  ('of', 'IN'),
#  ('1995', 'CD'),
#  ('As', 'IN'),
#  ('such', 'JJ'),
#  ('it', 'PRP'),
#  ('is', 'VBZ'),
#  ('subject', 'JJ'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('occurrence', 'NN'),
#  ('of', 'IN'),
#  ('many', 'JJ'),
#  ('events', 'NNS'),
#  ('outside', 'IN'),
#  ('AAON', 'NNP'),
#  ("'s", 'POS'),
#  ('control', 'NN'),
#  ('that', 'WDT'),
#  ('can', 'MD'),
#  ('cause', 'VB'),
#  ('AAON', 'NNP'),
#  ("'s", 'POS'),
#  ('results', 'NNS'),
#  ('to', 'TO'),
#  ('differ', 'VB'),
#  ('materially', 'RB'),
#  ('from', 'IN'),
#  ('those', 'DT'),
#  ('anticipated', 'VBN'),
#  ('Please', 'NNP'),
#  ('see', 'VB'),
#  ('the', 'DT'),
#  ('Risk', 'NNP'),
#  ('Factors', 'NNPS'),
#  ('contained', 'VBD'),
#  ('on', 'IN'),
#  ('our', 'PRP$'),
#  ('most', 'RBS'),
#  ('recent', 'JJ'),
#  ('Securities', 'NNP'),
#  ('and', 'CC'),
#  ('Exchange', 'NNP'),
#  ('Commission', 'NNP'),
#  ('filings', 'NNS'),
#  ('including', 'VBG'),
#  ('the', 'DT'),
#  ('annual', 'JJ'),
#  ('report', 'NN'),
#  ('on', 'IN'),
#  ('Form', 'NNP'),
#  ('10-K', 'JJ'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('quarterly', 'JJ'),
#  ('report', 'NN'),
#  ('on', 'IN'),
#  ('form', 'JJ'),
#  ('10-Q', 'JJ'),
#  ('I', 'PRP'),
#  ("'d", 'MD'),
#  ('like', 'VB'),
#  ('now', 'RB'),
#  ('to', 'TO'),
#  ('introduce', 'VB'),
#  ('our', 'PRP$'),
#  ('Vice', 'NNP'),
#  ('President', 'NNP'),
#  ('CFO', 'NNP'),
#  ('Kathy', 'NNP'),
#  ('Sheffield', 'NNP'),
#  ('who', 'WP'),
#  ('will', 'MD'),
#  ('give', 'VB'),
#  ('you', 'PRP'),
#  ('the', 'DT'),
#  ('numbers', 'NNS'),
#  ('Thank', 'NNP'),
#  ('you', 'PRP'),
#  ('Kathy', 'VB'),
#  ('KATHY', 'NNP'),
#  ('SHEFFIELD', 'NNP'),
#  ('VP', 'NNP'),
#  ('CFO', 'NNP'),
#  ('AAON', 'NNP'),
#  ('INC.', 'NNP'),
#  ('Good', 'JJ'),
#  ('afternoon', 'NN'),
#  ('I', 'PRP'),
#  ("'d", 'MD'),
#  ('like', 'VB'),
#  ('to', 'TO'),
#  ('welcome', 'VB'),
#  ('you', 'PRP'),
#  ('to', 'TO'),
#  ('our', 'PRP$'),
#  ('call', 'NN'),
#  ('also', 'RB'),
#  ('I', 'PRP'),
#  ("'ll", 'MD'),
#  ('begin', 'VB'),
#  ('today', 'NN'),
#  ('by', 'IN'),
#  ('discussing', 'VBG'),
#  ('the', 'DT'),
#  ('quarterly', 'JJ'),
#  ('results', 'NNS'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('three', 'CD'),
#  ('months', 'NNS'),
#  ('ended', 'VBD'),
#  ('2010', 'CD'),
#  ('compared', 'VBN'),
#  ('to', 'TO'),
#  ('December', 'NNP'),
#  ('31', 'CD'),
#  ('2009', 'CD'),
#  ('Our', 'PRP$'),
#  ('revenues', 'NNS'),
#  ('were', 'VBD'),
#  ('up', 'RB'),
#  ('21.4', 'CD'),
#  ('%', 'NN'),
#  ('to', 'TO'),
#  ('65.8', 'CD'),
#  ('million', 'CD'),
#  ('from', 'IN'),
#  ('54.2', 'CD'),
#  ('million', 'CD'),
#  ('Our', 'PRP$'),
#  ('revenues', 'NNS'),
#  ('increased', 'VBD'),
#  ('due', 'JJ'),
#  ('to', 'TO'),
#  ('a', 'DT'),
#  ('gained', 'VBN'),
#  ('additional', 'JJ'),
#  ('market', 'NN'),
#  ('share', 'NN'),
#  ('primarily', 'RB'),
#  ('as', 'IN'),
#  ('a', 'DT'),
#  ('result', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('favorable', 'JJ'),
#  ('reception', 'NN'),
#  ('of', 'IN'),
#  ('our', 'PRP$'),
#  ('new', 'JJ'),
#  ('products', 'NNS'),
#  ('and', 'CC'),
#  ('also', 'RB'),
#  ('to', 'TO'),
#  ('increased', 'VBN'),
#  ('market', 'NN'),
#  ('share', 'NN'),
#  ('Gross', 'NNP'),
#  ('profit', 'NN'),
#  ('decreased', 'VBD'),
#  ('4', 'CD'),
#  ('%', 'NN'),
#  ('to', 'TO'),
#  ('14.2', 'CD'),
#  ('million', 'CD'),
#  ('from', 'IN'),
#  ('14.8', 'CD'),
#  ('million', 'CD'),
#  ('Gross', 'NNP'),
#  ('profit', 'NN'),
#  ('was', 'VBD'),
#  ('21.6', 'CD'),
#  ('%', 'NN'),
#  ('of', 'IN'),
#  ('sales', 'NNS'),
#  ('during', 'IN'),
#  ('Q4', 'NNP'),
#  ('compared', 'VBN'),
#  ('to', 'TO'),
#  ('27.3', 'CD'),
#  ('%', 'NN'),
#  ('of', 'IN'),
#  ('sales', 'NNS'),
#  ('during', 'IN'),
#  ('Q4', 'NNP'),
#  ('of', 'IN'),
#  ('2009', 'CD'),
#  ('Our', 'PRP$'),
#  ('gross', 'JJ'),
#  ('profit', 'NN'),
#  ('percentages', 'NNS'),
#  ('decreased', 'VBN'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('absence', 'NN'),
#  ('of', 'IN'),
#  ('a', 'DT'),
#  ('derivative', 'JJ'),
#  ('that', 'IN'),
#  ('we', 'PRP'),
#  ('benefited', 'VBD'),
#  ('from', 'IN'),
#  ('in', 'IN'),
#  ('2009', 'CD'),
#  ('cost', 'NN'),
#  ('increases', 'NNS'),
#  ('led', 'VBN'),
#  ('by', 'IN'),
#  ('commodity', 'NN'),
#  ('prices', 'NNS'),
#  ('and', 'CC'),
#  ('our', 'PRP$'),
#  ('inability', 'NN'),
#  ('to', 'TO'),
#  ('implement', 'VB'),
#  ('price', 'NN'),
#  ('increases', 'NNS'),
#  ('given', 'VBN'),
#  ('the', 'DT'),
#  ('economic', 'JJ'),
#  ('environment', 'NN'),
#  ('that', 'IN'),
#  ('we', 'PRP'),
#  ('are', 'VBP'),
#  ('in', 'IN'),
#  ('Selling', 'VBG'),
#  ('general', 'JJ'),
#  ('and', 'CC'),
#  ('administrative', 'JJ'),
#  ('expenses', 'NNS'),
#  ('increased', 'VBD'),
#  ('14.2', 'CD'),
#  ('%', 'NN'),
#  ('to', 'TO'),
#  ('5.9', 'CD'),
#  ('billion', 'CD'),
#  ('or', 'CC'),
#  ('8.9', 'CD'),
#  ('%', 'NN'),
#  ('of', 'IN'),
#  ('sales', 'NNS'),
#  ('during', 'IN'),
#  ('the', 'DT'),
#  ('fourth', 'JJ'),
#  ('quarter', 'NN'),
#  ('from', 'IN'),
#  ('5.2', 'CD'),
#  ('million', 'CD'),
#  ('or', 'CC'),
#  ('9.5', 'CD'),
#  ('%', 'NN'),
#  ('of', 'IN'),
#  ('sales', 'NNS'),
#  ('The', 'DT'),
#  ('increase', 'NN'),
#  ('was', 'VBD'),
#  ('primarily', 'RB'),
#  ('due', 'JJ'),
#  ('to', 'TO'),
#  ('increased', 'VBN'),
#  ('bad', 'JJ'),
#  ('debt', 'NN'),
#  ('expense', 'NN'),
#  ('and', 'CC'),
#  ('selling-related', 'JJ'),
#  ('expenses', 'NNS'),
#  ('Operating', 'VBG'),
#  ('income', 'NN'),
#  ('decreased', 'VBD'),
#  ('to', 'TO'),
#  ('13.7', 'CD'),
#  ('%', 'NN'),
#  ('to', 'TO'),
#  ('8.3', 'CD'),
#  ('million', 'CD'),
#  ('or', 'CC'),
#  ('12.6', 'CD'),
#  ('%', 'NN'),
#  ('of', 'IN'),
#  ('sales', 'NNS'),
#  ('from', 'IN'),
#  ('9.6', 'CD'),
#  ('million', 'CD'),
#  ('or', 'CC'),
#  ('17.8', 'CD'),
#  ('%', 'NN'),
#  ('of', 'IN'),
#  ('sales', 'NNS'),
#  ('Net', 'JJ'),
#  ('income', 'NN'),
#  ('decreased', 'VBD'),
#  ('6.1', 'CD'),
#  ('%', 'NN'),
#  ('to', 'TO'),
#  ('5.8', 'CD'),
#  ('million', 'CD'),
#  ('or', 'CC'),
#  ('8.8', 'CD'),
#  ('%', 'NN'),
#  ('of', 'IN'),
#  ('sales', 'NNS'),
#  ('from', 'IN'),
#  ('6.2', 'CD'),
#  ('million', 'CD'),
#  ('or', 'CC'),
#  ('11.4', 'CD'),
#  ('%', 'NN'),
#  ('of', 'IN'),
#  ('sales', 'NNS'),
#  ('Diluted', 'VBN'),
#  ('earnings', 'NNS'),
#  ('per', 'IN'),
#  ('share', 'NN'),
#  ('was', 'VBD'),
#  ('0.35', 'CD'),
#  ('per', 'IN'),
#  ('share', 'NN'),
#  ('versus', 'IN'),
#  ('0.36', 'CD'),
#  ('per', 'IN'),
#  ('share', 'NN'),
#  ('a', 'DT'),
#  ('year', 'NN'),
#  ('ago', 'RB'),
#  ('Earnings', 'NNS'),
#  ('per', 'IN'),
#  ('share', 'NN'),
#  ('were', 'VBD'),
#  ('based', 'VBN'),
#  ('upon', 'IN'),
#  ('16,633,000', 'CD'),
#  ('shares', 'NNS'),
#  ('versus', 'VBD'),
#  ('17,281,000', 'CD'),
#  ('shares', 'NNS'),
#  ('the', 'DT'),
#  ('same', 'JJ'),
#  ('quarter', 'NN'),
#  ('a', 'DT'),
#  ('year', 'NN'),
#  ('ago', 'RB'),
#  ('The', 'DT'),
#  ('results', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('12', 'CD'),
#  ('months', 'NNS'),
#  ('or', 'CC'),
#  ('annual', 'JJ'),
#  ('revenues', 'NNS'),
#  ('were', 'VBD'),
#  ('substantially', 'RB'),
#  ('level', 'JJ'),
#  ('with', 'IN'),
#  ('the', 'DT'),
#  ('prior', 'JJ'),
#  ('year', 'NN'),
#  ('with', 'IN'),
#  ('only', 'RB'),
#  ('a', 'DT'),
#  ('slight', 'JJ'),
#  ('3.3', 'CD'),
#  ('%', 'NN'),
#  ('decrease', 'NN'),
#  ('to', 'TO'),
#  ('244.6', 'CD'),
#  ('million', 'CD'),
#  ('from', 'IN'),
#  ('245.3', 'CD'),
#  ('million', 'CD'),
#  ('in', 'IN'),
#  ('2009', 'CD'),
#  ('Gross', 'NNP'),
#  ('profit', 'NN'),
#  ('decreased', 'VBD'),
#  ('18.3', 'CD'),
#  ('%', 'NN'),
#  ('to', 'TO'),
#  ('55.2', 'CD'),
#  ('million', 'CD'),
#  ('from', 'IN'),
#  ('67.5', 'CD'),
#  ('million', 'CD'),
#  ('Our', 'PRP$'),
#  ('gross', 'JJ'),
#  ('profit', 'NN'),
#  ('was', 'VBD'),
#  ('22.6', 'CD'),
#  ('%', 'NN'),
#  ('of', 'IN'),
#  ('sales', 'NNS'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('12', 'CD'),
#  ('months', 'NNS'),
#  ('of', 'IN'),
#  ('2010', 'CD'),
#  ('compared', 'VBN'),
#  ('to', 'TO'),
#  ('27.5', 'CD'),
#  ('%', 'NN'),
#  ('in', 'IN'),
#  ('2009', 'CD'),
#  ('In', 'IN'),
#  ('addition', 'NN'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('reason', 'NN'),
#  ('mentioned', 'VBD'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('quarterly', 'JJ'),
#  ('discussion', 'NN'),
#  ('gross', 'JJ'),
#  ('profit', 'NN'),
#  ('was', 'VBD'),
#  ('affected', 'VBN'),
#  ('by', 'IN'),
#  ('one-time', 'JJ'),
#  ('costs', 'NNS'),
#  ('associated', 'VBN'),
#  ('with', 'IN'),
#  ('relocation', 'NN'),
#  ('of', 'IN'),
#  ('production', 'NN'),
#  ('line', 'NN'),
#  ('and', 'CC'),
#  ('also', 'RB'),
#  ('the', 'DT'),
#  ('addition', 'NN'),
#  ('of', 'IN'),
#  ('production', 'NN'),
#  ('facilities', 'NNS'),
#  ('Selling', 'NNP'),
#  ('general', 'JJ'),
#  ('and', 'CC'),
#  ('administrative', 'JJ'),
#  ('expenses', 'NNS'),
#  ('decreased', 'VBD'),
#  ('5.5', 'CD'),
#  ('%', 'NN'),
#  ('to', 'TO'),
#  ('22.5', 'CD'),
#  ('million', 'CD'),
#  ('or', 'CC'),
#  ('9.2', 'CD'),
#  ('%', 'NN'),
#  ('of', 'IN'),
#  ('sales', 'NNS'),
#  ('from', 'IN'),
#  ('23.8', 'CD'),
#  ('million', 'CD'),
#  ('or', 'CC'),
#  ('9.7', 'CD'),
#  ('%', 'NN'),
#  ('of', 'IN'),
#  ('sales', 'NNS'),
#  ('Decrease', 'NNP'),
#  ('was', 'VBD'),
#  ('primarily', 'RB'),
#  ('due', 'JJ'),
#  ('to', 'TO'),
#  ('a', 'DT'),
#  ('decrease', 'NN'),
#  ('in', 'IN'),
#  ('profit', 'NN'),
#  ('sharing', 'NN'),
#  ('related', 'VBN'),
#  ('to', 'TO'),
#  ('a', 'DT'),
#  ('lower', 'JJR'),
#  ('net', 'JJ'),
#  ('income', 'NN'),
#  ('Operating', 'VBG'),
#  ('income', 'NN'),
#  ('decreased', 'VBD'),
#  ('25.2', 'CD'),
#  ('%', 'NN'),
#  ('to', 'TO'),
#  ('32.7', 'CD'),
#  ('million', 'CD'),
#  ('or', 'CC'),
#  ('13.4', 'CD'),
#  ('%', 'NN'),
#  ('of', 'IN'),
#  ('sales', 'NNS'),
#  ('from', 'IN'),
#  ('43.8', 'CD'),
#  ('million', 'CD'),
#  ('or', 'CC'),
#  ('17.8', 'CD'),
#  ('%', 'NN'),
#  ('of', 'IN'),
#  ('sales', 'NNS'),
#  ('Net', 'JJ'),
#  ('income', 'NN'),
#  ('decreased', 'VBD'),
#  ('21', 'CD'),
#  ('%', 'NN'),
#  ('to', 'TO'),
#  ('21.9', 'CD'),
#  ('million', 'CD'),
#  ('or', 'CC'),
#  ('9', 'CD'),
#  ('%', 'NN'),
#  ('of', 'IN'),
#  ('sales', 'NNS'),
#  ('from', 'IN'),
#  ('27.7', 'CD'),
#  ('million', 'CD'),
#  ('or', 'CC'),
#  ('11.3', 'CD'),
#  ('%', 'NN'),
#  ('of', 'IN'),
#  ('sales', 'NNS'),
#  ('Diluted', 'VBD'),
#  ('EPS', 'NNP'),
#  ('was', 'VBD'),
#  ('a', 'DT'),
#  ('1.30', 'CD'),
#  ('per', 'IN'),
#  ('share', 'NN'),
#  ('versus', 'IN'),
#  ('1.60', 'CD'),
#  ('per', 'IN'),
#  ('share', 'NN'),
#  ('Earnings', 'NNS'),
#  ('per', 'IN'),
#  ('shares', 'NNS'),
#  ('were', 'VBD'),
#  ('based', 'VBN'),
#  ('on', 'IN'),
#  ('16,893,000', 'CD'),
#  ('shares', 'NNS'),
#  ('versus', 'VBD'),
#  ('17,309,000', 'CD'),
#  ('shares', 'NNS'),
#  ('the', 'DT'),
#  ('same', 'JJ'),
#  ('period', 'NN'),
#  ('a', 'DT'),
#  ('year', 'NN'),
#  ('ago', 'RB'),
#  ('Our', 'PRP$'),
#  ('effective', 'JJ'),
#  ('tax', 'NN'),
#  ('rate', 'NN'),
#  ('decreased', 'VBN'),
#  ('from', 'IN'),
#  ('37', 'CD'),
#  ('%', 'NN'),
#  ('to', 'TO'),
#  ('33', 'CD'),
#  ('%', 'NN'),
#  ('due', 'JJ'),
#  ('to', 'TO'),
#  ('an', 'DT'),
#  ('increase', 'NN'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('domestic', 'JJ'),
#  ('production', 'NN'),
#  ('activity', 'NN'),
#  ('tax', 'NN'),
#  ('credit', 'NN'),
#  ('from', 'IN'),
#  ('6', 'CD'),
#  ('%', 'NN'),
#  ('to', 'TO'),
#  ('9', 'CD'),
#  ('%', 'NN'),
#  ('higher', 'JJR'),
#  ('R', 'NNP'),
#  ('&', 'CC'),
#  ('D', 'NNP'),
#  ('credits', 'NNS'),
#  ('than', 'IN'),
#  ('we', 'PRP'),
#  ('anticipated', 'VBD'),
#  ('and', 'CC'),
#  ('other', 'JJ'),
#  ('domestic', 'JJ'),
#  ('credits', 'NNS'),
#  ('We', 'PRP'),
#  ('expect', 'VBP'),
#  ('that', 'IN'),
#  ('our', 'PRP$'),
#  ('effective', 'JJ'),
#  ('rate', 'NN'),
#  ('to', 'TO'),
#  ('be', 'VB'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('range', 'NN'),
#  ('of', 'IN'),
#  ('33', 'CD'),
#  ('%', 'NN'),
#  ('to', 'TO'),
#  ('35', 'CD'),
#  ('%', 'NN'),
#  ('for', 'IN'),
#  ('2011', 'CD'),
#  ('Moving', 'VBG'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('balance', 'NN'),
#  ('sheet', 'NN'),
#  ('we', 'PRP'),
#  ('see', 'VBP'),
#  ('that', 'IN'),
#  ('we', 'PRP'),
#  ('continue', 'VBP'),
#  ('to', 'TO'),
#  ('have', 'VB'),
#  ('a', 'DT'),
#  ('strong', 'JJ'),
#  ('liquidity', 'NN'),
#  ('position', 'NN'),
#  ('of', 'IN'),
#  ('2.4', 'CD'),
#  ('million', 'CD'),
#  ('in', 'IN'),
#  ('cash', 'NN'),
#  ('and', 'CC'),
#  ('no', 'DT'),
#  ('long-term', 'JJ'),
#  ('debt', 'NN'),
#  ('Our', 'PRP$'),
#  ('current', 'JJ'),
#  ('ratio', 'NN'),
#  ('was', 'VBD'),
#  ('2.5', 'CD'),
#  ('to', 'TO'),
#  ('1', 'CD'),
#  ('capital', 'NN'),
#  ('expenditures', 'NNS'),
#  ('were', 'VBD'),
#  ('17.5', 'CD'),
#  ('million', 'CD'),
#  ('for', 'IN'),
#  ('manufacturing', 'NN'),
#  ('and', 'CC'),
#  ('equipment', 'NN'),
#  ('purchases', 'NNS'),
#  ('and', 'CC'),
#  ('costs', 'NNS'),
#  ('to', 'TO'),
#  ('expand', 'VB'),
#  ('our', 'PRP$'),
#  ('manufacturing', 'NN'),
#  ('facilities', 'NNS'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('Tulsa', 'NNP'),
#  ('location', 'NN'),
#  ('Shareholders', 'NNS'),
#  ("'", 'POS'),
#  ('equity', 'NN'),
#  ('per', 'IN'),
#  ('share', 'NN'),
#  ('is', 'VBZ'),
#  ('7.07', 'CD'),
#  ('compared', 'VBN'),
#  ('to', 'TO'),
#  ('6.85', 'CD'),
#  ('for', 'IN'),
#  ('2009', 'CD'),
#  ('We', 'PRP'),
#  ('paid', 'VBD'),
#  ('cash', 'NN'),
#  ('dividends', 'NNS'),
#  ('of', 'IN'),
#  ('9.2', 'CD'),
#  ('million', 'CD'),
#  ('in', 'IN'),
#  ('2010', 'CD'),
#  ('I', 'PRP'),
#  ("'d", 'MD'),
#  ('now', 'RB'),
#  ('like', 'IN'),
#  ('to', 'TO'),
#  ('turn', 'VB'),
#  ('the', 'DT'),
#  ('call', 'NN'),
#  ('over', 'IN'),
#  ('to', 'TO'),
#  ('Norm', 'NNP'),
#  ('who', 'WP'),
#  ('will', 'MD'),
#  ('discuss', 'VB'),
#  ('our', 'PRP$'),
#  ('results', 'NNS'),
#  ('in', 'IN'),
#  ('further', 'JJ'),
#  ('detail', 'NN'),
#  ('along', 'IN'),
#  ('with', 'IN'),
#  ('new', 'JJ'),
#  ('products', 'NNS'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('outlook', 'NN'),
#  ('for', 'IN'),
#  ('2011', 'CD'),
#  ('Norm', 'VB'),
#  ('NORMAN', 'NNP'),
#  ('ASBJORNSON', 'NNP'),
#  ('Thank', 'NN'),
#  ('you', 'PRP'),
#  ('Kathy', 'NNP'),
#  ('The', 'DT'),
#  ('increase', 'NN'),
#  ('of', 'IN'),
#  ('21', 'CD'),
#  ('%', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('late', 'JJ'),
#  ('third', 'JJ'),
#  ('quarter', 'NN'),
#  ('or', 'CC'),
#  ('fourth', 'JJ'),
#  ('quarter', 'NN'),
#  ('in', 'IN'),
#  ('2010', 'CD'),
#  ('plus', 'IN'),
#  ('2009', 'CD'),
#  ('should', 'MD'),
#  ('also', 'RB'),
#  ('be', 'VB'),
#  ('noted', 'VBN'),
#  ('that', 'IN'),
#  ('the', 'DT'),
#  ('marketplace', 'NN'),
#  ('as', 'RB'),
#  ('near', 'IN'),
#  ('as', 'IN'),
#  ('we', 'PRP'),
#  ('could', 'MD'),
#  ('tell', 'VB'),
#  ('was', 'VBD'),
#  ('down', 'RB'),
#  ('approximately', 'RB'),
#  ('14', 'CD'),
#  ('%', 'NN'),
#  ('last', 'JJ'),
#  ('year', 'NN'),
#  ('compared', 'VBN'),
#  ('to', 'TO'),
#  ('2009', 'CD'),
#  ('So', 'IN'),
#  ('what', 'WP'),
#  ('it', 'PRP'),
#  ('really', 'RB'),
#  ('meant', 'JJ'),
#  ('is', 'VBZ'),
#  ('we', 'PRP'),
#  ('took', 'VBD'),
#  ('about', 'RB'),
#  ('35', 'CD'),
#  ('%', 'NN'),
#  ('of', 'IN'),
#  ('our', 'PRP$'),
#  ('sales', 'NNS'),
#  ('from', 'IN'),
#  ('our', 'PRP$'),
#  ('competitors', 'NNS'),
#  ('in', 'IN'),
#  ('that', 'DT'),
#  ('quarter', 'NN'),
#  ('so', 'IN'),
#  ('we', 'PRP'),
#  ('had', 'VBD'),
#  ('quite', 'RB'),
#  ('a', 'DT'),
#  ('remarkable', 'JJ'),
#  ('increase', 'NN'),
#  ('in', 'IN'),
#  ('market', 'NN'),
#  ('share', 'NN'),
#  ('last', 'JJ'),
#  ('quarter', 'NN'),
#  ('The', 'DT'),
#  ('new', 'JJ'),
#  ('products', 'NNS'),
#  ('are', 'VBP'),
#  ('now', 'RB'),
#  ('pretty', 'RB'),
#  ('well', 'RB'),
#  ('all', 'RB'),
#  ('introduced', 'VBN'),
#  ('as', 'RB'),
#  ('far', 'RB'),
#  ('as', 'IN'),
#  ('the', 'DT'),
#  ('rooftops', 'NNS'),
#  ('are', 'VBP'),
#  ('concerned', 'JJ'),
#  ('and', 'CC'),
#  ('now', 'RB'),
#  ('we', 'PRP'),
#  ("'ve", 'VBP'),
#  ('turned', 'VBN'),
#  ('our', 'PRP$'),
#  ('attention', 'NN'),
#  ('over', 'IN'),
#  ('to', 'TO'),
#  ('chilled', 'JJ'),
#  ('water', 'NN'),
#  ...]

# %%
len(txtfiles)
# Out:
# 10578

# %%
filo = rrr[:3]

# %%
words_file = "words.txt"
dill = {}


for coy in filo:


    input_file = mypath + coy

    coy_name = coy[:-4]

    dill[coy_name] = {}
    
    curriculum_words = []
    pos_tagged_array = []
    base_words = []
    wordnet_lemmatizer = WordNetLemmatizer()


    process_words_file()
    process_input()
    lemmatize_words()

    for curriculum_word in curriculum_words:
        count = base_words.count(curriculum_word)

        dill[coy_name][curriculum_word] = count
    dill[coy_name]["doc_length"] = doc_len

# %%
import pandas as pd
df = pd.DataFrame.from_dict(dill).T

df["year"] = list(df.index.values)

df["year"] = df["year"].apply(lambda x: x[-4:])

# %%
df["sum_words"] = df.drop(["doc_length","year"],axis=1).sum(axis=1)

# %%
df["Words/Doc %"] = (df["sum_words"]/df["doc_length"])*100

# %%
df.head()
# Out:
#            acquisition  doc_length  execute  long-term  merger  mergers  \
# 3M_Co2009           21       77776        2         30       2        0
# 3M_Co2010           52      149541        9         77       1        0
# 3M_Co2011           34       90435        2         20       0        0
#
#            pricing  strategy  year  sum_words  Words/Doc %
# 3M_Co2009       14        25  2009         94     0.120860
# 3M_Co2010       66       111  2010        316     0.211313
# 3M_Co2011       44        57  2011        157     0.173605

# %%
dill
# Out:
# {'3Com_Corp2009': {'acquisition': 0,
#   'execute': 4,
#   'long-term': 8,
#   'merger': 1,
#   'mergers': 0,
#   'pricing': 12,
#   'strategy': 94},
#  '3D_Systems_Corp2012': {'acquisition': 84,
#   'execute': 3,
#   'long-term': 7,
#   'merger': 0,
#   'mergers': 0,
#   'pricing': 4,
#   'strategy': 22},
#  '3D_Systems_Corp2013': {'acquisition': 11,
#   'execute': 1,
#   'long-term': 3,
#   'merger': 0,
#   'mergers': 0,
#   'pricing': 0,
#   'strategy': 4},
#  '3D_Systems_Corp2014': {'acquisition': 43,
#   'execute': 7,
#   'long-term': 17,
#   'merger': 0,
#   'mergers': 1,
#   'pricing': 6,
#   'strategy': 21},
#  '3D_Systems_Corp2015': {'acquisition': 29,
#   'execute': 1,
#   'long-term': 17,
#   'merger': 0,
#   'mergers': 0,
#   'pricing': 10,
#   'strategy': 21},
#  '3D_Systems_Corp2016': {'acquisition': 12,
#   'execute': 8,
#   'long-term': 18,
#   'merger': 0,
#   'mergers': 0,
#   'pricing': 6,
#   'strategy': 62},
#  '3M_Co2009': {'acquisition': 21,
#   'execute': 2,
#   'long-term': 30,
#   'merger': 2,
#   'mergers': 0,
#   'pricing': 14,
#   'strategy': 25},
#  '3M_Co2010': {'acquisition': 52,
#   'execute': 9,
#   'long-term': 77,
#   'merger': 1,
#   'mergers': 0,
#   'pricing': 66,
#   'strategy': 111},
#  '3M_Co2011': {'acquisition': 34,
#   'execute': 2,
#   'long-term': 20,
#   'merger': 0,
#   'mergers': 0,
#   'pricing': 44,
#   'strategy': 57},
#  '3M_Co2012': {'acquisition': 29,
#   'execute': 12,
#   'long-term': 23,
#   'merger': 1,
#   'mergers': 1,
#   'pricing': 47,
#   'strategy': 20},
#  '3M_Co2013': {'acquisition': 38,
#   'execute': 5,
#   'long-term': 22,
#   'merger': 0,
#   'mergers': 0,
#   'pricing': 43,
#   'strategy': 33},
#  '3M_Co2014': {'acquisition': 53,
#   'execute': 19,
#   'long-term': 25,
#   'merger': 1,
#   'mergers': 0,
#   'pricing': 36,
#   'strategy': 80},
#  '3M_Co2015': {'acquisition': 51,
#   'execute': 36,
#   'long-term': 16,
#   'merger': 1,
#   'mergers': 8,
#   'pricing': 33,
#   'strategy': 100},
#  '3M_Co2016': {'acquisition': 33,
#   'execute': 32,
#   'long-term': 34,
#   'merger': 4,
#   'mergers': 8,
#   'pricing': 57,
#   'strategy': 99},
#  '8x8_Inc2014': {'acquisition': 40,
#   'execute': 5,
#   'long-term': 2,
#   'merger': 0,
#   'mergers': 0,
#   'pricing': 12,
#   'strategy': 18},
#  '8x8_Inc2015': {'acquisition': 37,
#   'execute': 6,
#   'long-term': 5,
#   'merger': 0,
#   'mergers': 1,
#   'pricing': 19,
#   'strategy': 47},
#  '8x8_Inc2016': {'acquisition': 23,
#   'execute': 5,
#   'long-term': 3,
#   'merger': 0,
#   'mergers': 0,
#   'pricing': 3,
#   'strategy': 17},
#  'AAON_Inc2009': {'acquisition': 0,
#   'execute': 0,
#   'long-term': 2,
#   'merger': 0,
#   'mergers': 0,
#   'pricing': 4,
#   'strategy': 1},
#  'AAON_Inc2010': {'acquisition': 0,
#   'execute': 0,
#   'long-term': 2,
#   'merger': 0,
#   'mergers': 0,
#   'pricing': 1,
#   'strategy': 0},
#  'ANN_Inc2009': {'acquisition': 0,
#   'execute': 4,
#   'long-term': 3,
#   'merger': 0,
#   'mergers': 0,
#   'pricing': 13,
#   'strategy': 50}}

# %%
from textblob import TextBlob
words = "cat dog child goose pants"
blob = TextBlob(ra)
plurals = [word.pluralize() for word in blob.words]
