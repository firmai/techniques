# %%
import psycopg2
import pandas.io.sql as psql

conn = psycopg2.connect(database="terra", user = "postgres", password = "D13app3lman!", host = "127.0.0.1", port = "5432")

# %%
## Easy read in fro the sql database
dataframe = psql.read_sql(
    
"SELECT * FROM people \
WHERE attrition ='True' \
AND (yearsincurrentrole + yearssincelastpromotion) > 6\
OR yearsincurrentrole > 15", conn)

# %%
dataframe.shape
# Out:
# (75, 35)

# %%
dataframe.shape
# Out:
# (62, 35)

# %%
dataframe.head()
# Out:
#    age  attrition     businesstravel  dailyrate              department  \
# 0   32       True  Travel_Frequently       1125  Research & Development
# 1   41       True      Travel_Rarely       1360  Research & Development
# 2   59      False      Travel_Rarely       1435                   Sales
# 3   46       True      Travel_Rarely        669                   Sales
# 4   34       True  Travel_Frequently        658  Research & Development
#
#    distancefromhome  education    educationfield  employeecount  \
# 0                16          1     Life Sciences              1
# 1                12          3  Technical Degree              1
# 2                25          3     Life Sciences              1
# 3                 9          2           Medical              1
# 4                 7          3     Life Sciences              1
#
#    employeenumber          ...           relationshipsatisfaction  \
# 0              33          ...                                  2
# ...
