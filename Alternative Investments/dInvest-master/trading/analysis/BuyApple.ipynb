# %%
# %matplotlib inline
import pandas as pd
import pyfolio as pf

# %%
perf = pd.read_pickle('results/value2016-10-25.pickle')
perf.head()
# Out:
# /home/nud3l/GitHub/pyfolio/pyfolio/lib/python3.4/site-packages/pandas/tseries/index.py:755: PerformanceWarning: Non-vectorized DateOffset being applied to Series or DatetimeIndex
#   PerformanceWarning)
# /home/nud3l/GitHub/pyfolio/pyfolio/lib/python3.4/site-packages/pandas/tseries/index.py:755: PerformanceWarning: Non-vectorized DateOffset being applied to Series or DatetimeIndex
#   PerformanceWarning)
# /home/nud3l/GitHub/pyfolio/pyfolio/lib/python3.4/site-packages/pandas/tseries/index.py:755: PerformanceWarning: Non-vectorized DateOffset being applied to Series or DatetimeIndex
#   PerformanceWarning)
#                      AAPL  algo_volatility  algorithm_period_return  alpha  \
# 2016-10-20 20:00:00   NaN              NaN                        0    NaN
# 2016-10-21 20:00:00   NaN                0                        0      0
# 2016-10-24 20:00:00   NaN                0                        0      0
# ...

# %%
returns, positions, transactions, gross_lev = pf.utils.extract_rets_pos_txn_from_zipline(perf)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-072c55d8e3c2> in <module>()
# ----> 1 returns, positions, transactions, gross_lev = pf.utils.extract_rets_pos_txn_from_zipline(perf)
#
# /home/nud3l/GitHub/pyfolio/pyfolio/lib/python3.4/site-packages/pyfolio/utils.py in extract_rets_pos_txn_from_zipline(backtest)
#     412         raise ValueError("The backtest does not have any positions.")
#     413     positions = pd.concat(raw_positions)
# --> 414     positions = pos.extract_pos(positions, backtest.ending_cash)
#     415     transactions = txn.make_transaction_frame(backtest.transactions)
#     416     if transactions.index.tzinfo is None:
#
# /home/nud3l/GitHub/pyfolio/pyfolio/lib/python3.4/site-packages/pyfolio/pos.py in extract_pos(positions, cash)
#     150     """
#     151     positions = positions.copy()
# ...
