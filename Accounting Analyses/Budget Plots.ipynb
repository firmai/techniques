# %%
### Need Altair to work first

# %%
import pandas as pd
import altair as alt
# Out:
# /Users/dereksnow/anaconda/envs/py36/lib/python3.6/site-packages/requests/__init__.py:80: RequestsDependencyWarning: urllib3 (1.22) or chardet (2.3.0) doesn't match a supported version!
#   RequestsDependencyWarning)

# %%
alt.renderers.enable('notebook')
# Out:
# RendererRegistry.enable('notebook')

# %% [raw]
# !conda install -c conda-forge altair vega_datasets notebook vega

# %%
# %matplotlib inline

# %%
budget = pd.read_csv("data/mn-budget-detail-2014.csv")

# %%
budget.head()
# Out:
#                   category                                             detail  \
# 0  UNIVERSITY OF MINNESOTA      Higher Education Asset Preservation (HEAPR) 1
# 1  UNIVERSITY OF MINNESOTA            Minneapolis; Tate Laboratory Renovation
# 2  UNIVERSITY OF MINNESOTA                         Crookston; Wellness Center
# 3  UNIVERSITY OF MINNESOTA                              Research Laboratories
# 4  UNIVERSITY OF MINNESOTA  Duluth; Chemical Sciences and Advanced Materia...
#
#      amount
# 0  42500000
# 1  56700000
# 2  10000000
# 3   8667000
# 4   1500000

# %%
budget_top_10 = budget.sort_values(by='amount',ascending=False)[:10]
budget_top_10.plot(kind="bar",x=budget_top_10["detail"],
                   title="MN Capital Budget - 2014",
                   legend=False)

# %%
alt.Chart(budget_top_10).mark_bar().encode(
    x='detail',
    y='amount')
# Out:
# <div class="vega-embed" id="d9c57045-62bf-407c-b29f-13a07e507ee3"></div>
#
# <style>
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 14px;
# }
# </style>

# %%
alt.Chart(budget_top_10).mark_bar().encode(
    x='detail',
    y='amount',
    color="category"
)
# Out:
# <div class="vega-embed" id="f545398c-5d99-4f66-a164-d2429cd3a809"></div>
#
# <style>
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 14px;
# }
# </style>

# %%
import altair as alt
from vega_datasets import data

# for the notebook only (not for JupyterLab) run this command once per session
alt.renderers.enable('notebook')

iris = data.iris()

alt.Chart(iris).mark_point().encode(
    x='petalLength',
    y='petalWidth',
    color='species'
)
# Out:
# <div class="vega-embed" id="1086b5a5-f967-4417-ae78-5692dac3c168"></div>
#
# <style>
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 14px;
# }
# </style>
